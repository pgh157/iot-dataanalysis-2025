# %% [markdown]
# ## YOLO
#
# ### PyTorch 기반 물체인식 모델
# - CNN, rCNN(Regions with CNN)
#
# #### YOLOv5 이상 설치
# ```shell
# > pip install ultralytics
# ```

# %%
# YOLO 설치
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.109-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (3.10.1)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (11.1.0)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests>=2.23.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (2.6.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (0.21.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (7.0.0)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: networkx in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.109-py3-none-any.whl (974 kB)
#    ---------------------------------------- 0.0/974.8 kB ? eta -:--:--
#    -------------- ------------------------ 368.6/974.8 kB 11.6 MB/s eta 0:00:01
#    --------------------------------------  972.8/974.8 kB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 974.8/974.8 kB 8.8 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.5 MB 21.6 MB/s eta 0:00:02
#    - -------------------------------------- 1.0/39.5 MB 22.0 MB/s eta 0:00:02
#    - -------------------------------------- 1.0/39.5 MB 22.0 MB/s eta 0:00:02
#    - -------------------------------------- 1.3/39.5 MB 7.1 MB/s eta 0:00:06
#    -- ------------------------------------- 2.5/39.5 MB 10.7 MB/s eta 0:00:04
#    --- ------------------------------------ 3.9/39.5 MB 13.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.3/39.5 MB 16.0 MB/s eta 0:00:03
#    ------ --------------------------------- 6.3/39.5 MB 16.7 MB/s eta 0:00:02
#    -------- ------------------------------- 8.3/39.5 MB 19.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.2/39.5 MB 24.2 MB/s eta 0:00:02
#    -------------- ------------------------- 13.9/39.5 MB 43.7 MB/s eta 0:00:01
#    --------------- ------------------------ 15.7/39.5 MB 46.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 17.3/39.5 MB 46.7 MB/s eta 0:00:01
#    -------------------- ------------------- 20.0/39.5 MB 46.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.6/39.5 MB 46.7 MB/s eta 0:00:01
#    ------------------------- -------------- 25.3/39.5 MB 50.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.3/39.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------------- -------- 30.8/39.5 MB 54.4 MB/s eta 0:00:01
#    --------------------------------- ------ 33.5/39.5 MB 59.8 MB/s eta 0:00:01
#    ------------------------------------ --- 36.3/39.5 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  39.5/39.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 40.9 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
#    ---------------------------------------- 0.0/162.0 kB ? eta -:--:--
#    ---------------------------------------- 162.0/162.0 kB 9.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, pyyaml, opencv-python, ultralytics-thop, ultralytics
# Successfully installed opencv-python-4.11.0.86 py-cpuinfo-9.0.0 pyyaml-6.0.2 ultralytics-8.3.109 ultralytics-thop-2.0.14
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### 콘솔에서 예측

# %%
# 콘솔에서 예측
## yolo11n.pt - pretrained YOLO model
## 자동으로 yolo11n.pt 다운로드
## 웹 URL에 있는 이미지도 예측이 가능
# !yolo predict model = yolo11n.pt source = './bus.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# Ultralytics 8.3.109 🚀 Python-3.11.9 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 c:\source\iot-dataanalysis-2025\day08\bus.jpg: 640x480 4 persons, 1 bus, 34.0ms
# Speed: 3.9ms preprocess, 34.0ms inference, 113.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\source\iot-dataanalysis-2025\runs\detect\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/5.35M [00:00<?, ?B/s]
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 76.8MB/s]

# %% [markdown]
# #### 파이썬으로 예측

# %%
# YOLO 모듈 로드
from ultralytics import YOLO

# %%
# YOLO 클래스가 들어오는 모델의 버전에 따라 알아서 YOLO 예측모델 객체 생성
model = YOLO('./yolo11n.pt')

# %% [markdown]
# ##### coco8.yml
# - https://github.com/ultralytics/assets/releases/download/v0.0.0/coco8.zip
# - 위 내용대로 훈련을 시킨 결과 -> yolo11n.pt

# %%
# coco8.yaml - YOLO 훈련에 사용할 데이터셋 정의파일
train_results = model.train(
    data = './coco8.yaml',
    epochs = 100,
    imgsz = 640,
    device ='cuda:0'
)
# Out:
# Ultralytics 8.3.109  Python-3.11.9 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# engine\trainer: task=detect, mode=train, model=./yolo11n.pt, data=./coco8.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=C:\source\iot-dataanalysis-2025\runs\detect\train2
#
# Dataset 'coco8.yaml' images not found , missing path 'C:\source\datasets\coco8\images\val'
# Downloading https://ultralytics.com/assets/coco8.zip to 'C:\source\datasets\coco8.zip'...
# 100%|██████████| 433k/433k [00:00<00:00, 24.6MB/s]
# Unzipping C:\source\datasets\coco8.zip to C:\source\datasets\coco8...: 100%|██████████| 25/25 [00:00<00:00, 937.87file/s]
# Dataset download success  (1.0s), saved to C:\source\datasets
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\Admin\AppData\Roaming\Ultralytics\Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 7.82MB/s]
# WARNING:tensorflow:From c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir C:\source\iot-dataanalysis-2025\runs\detect\train2', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: checks failed . AMP training on NVIDIA GeForce GTX 1650 GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Scanning C:\source\datasets\coco8\labels\train... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<00:00, 235.75it/s]
# train: New cache created: C:\source\datasets\coco8\labels\train.cache
# val: Scanning C:\source\datasets\coco8\labels\val... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<00:00, 1136.82it/s]
# val: New cache created: C:\source\datasets\coco8\labels\val.cache
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # coco8.yaml - YOLO 훈련에 사용할 데이터셋 정의파일
# ----> 2 train_results = model.train(
#       3     data = './coco8.yaml',
#       4     epochs = 100,
#       5     imgsz = 640,
#       6     device ='cuda:0'
#       7 )
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\engine\model.py:791, in Model.train(self, trainer, **kwargs)
#     788     self.model = self.trainer.model
#     790 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 791 self.trainer.train()
#     792 # Update model and cfg after training
#     793 if RANK in {-1, 0}:
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\engine\trainer.py:211, in BaseTrainer.train(self)
#     208         ddp_cleanup(self, str(file))
#     210 else:
# --> 211     self._do_train(world_size)
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\engine\trainer.py:327, in BaseTrainer._do_train(self, world_size)
#     325 if world_size > 1:
#     326     self._setup_ddp(world_size)
# --> 327 self._setup_train(world_size)
#     329 nb = len(self.train_loader)  # number of batches
#     330 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\engine\trainer.py:294, in BaseTrainer._setup_train(self, world_size)
#     291 self.train_loader = self.get_dataloader(self.trainset, batch_size=batch_size, rank=LOCAL_RANK, mode="train")
#     292 if RANK in {-1, 0}:
#     293     # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
# --> 294     self.test_loader = self.get_dataloader(
#     295         self.testset, batch_size=batch_size if self.args.task == "obb" else batch_size * 2, rank=-1, mode="val"
#     296     )
#     297     self.validator = self.get_validator()
#     298     metric_keys = self.validator.metrics.keys + self.label_loss_items(prefix="val")
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\models\yolo\detect\train.py:88, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#      86     shuffle = False
#      87 workers = self.args.workers if mode == "train" else self.args.workers * 2
# ---> 88 return build_dataloader(dataset, batch_size, workers, shuffle, rank)
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\data\build.py:169, in build_dataloader(dataset, batch, workers, shuffle, rank)
#     167 generator = torch.Generator()
#     168 generator.manual_seed(6148914691236517205 + RANK)
# --> 169 return InfiniteDataLoader(
#     170     dataset=dataset,
#     171     batch_size=batch,
#     172     shuffle=shuffle and sampler is None,
#     173     num_workers=nw,
#     174     sampler=sampler,
#     175     pin_memory=PIN_MEMORY,
#     176     collate_fn=getattr(dataset, "collate_fn", None),
#     177     worker_init_fn=seed_worker,
#     178     generator=generator,
#     179 )
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\ultralytics\data\build.py:50, in InfiniteDataLoader.__init__(self, *args, **kwargs)
#      48 super().__init__(*args, **kwargs)
#      49 object.__setattr__(self, "batch_sampler", _RepeatSampler(self.batch_sampler))
# ---> 50 self.iterator = super().__iter__()
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\torch\utils\data\dataloader.py:491, in DataLoader.__iter__(self)
#     489     return self._iterator
#     490 else:
# --> 491     return self._get_iterator()
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\torch\utils\data\dataloader.py:422, in DataLoader._get_iterator(self)
#     420 else:
#     421     self.check_worker_number_rationality()
# --> 422     return _MultiProcessingDataLoaderIter(self)
#
# File c:\source\iot-dataanalysis-2025\mlvenv\Lib\site-packages\torch\utils\data\dataloader.py:1146, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1139 w.daemon = True
#    1140 # NB: Process.start() actually take some time as it needs to
#    1141 #     start a process and pass the arguments over via a pipe.
#    1142 #     Therefore, we only add a worker to self._workers list after
#    1143 #     it started, so that we do not call .join() if program dies
#    1144 #     before it starts, and __del__ tries to join but will get:
#    1145 #     AssertionError: can only join a started process.
# -> 1146 w.start()
#    1147 self._index_queues.append(index_queue)
#    1148 self._workers.append(w)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\multiprocessing\context.py:336, in SpawnProcess._Popen(process_obj)
#     333 @staticmethod
#     334 def _Popen(process_obj):
#     335     from .popen_spawn_win32 import Popen
# --> 336     return Popen(process_obj)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\multiprocessing\popen_spawn_win32.py:72, in Popen.__init__(self, process_obj)
#      68     env = None
#      70 cmd = ' '.join('"%s"' % x for x in cmd)
# ---> 72 with open(wfd, 'wb', closefd=True) as to_child:
#      73     # start process
#      74     try:
#      75         hp, ht, pid, tid = _winapi.CreateProcess(
#      76             python_exe, cmd,
#      77             None, None, False, 0, env, None, None)
#
# KeyboardInterrupt:

# %% [markdown]
# #### 이미지 예측

# %%
result = model('./0000001.jpg')
# Out:
# image 1/1 c:\source\iot-dataanalysis-2025\day08\0000001.jpg: 480x640 1 cat, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 87.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
# maptplotlib 모듈 로드
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# %%
# 예측결과 이미지 저장
img = result[0].plot()
img_pil =  Image.fromarray(img[..., ::-1])
img_pil.save('./predict_result.jpg')

# %% [markdown]
# ### OpenCV
# - Open Source Computer Vision 약자. 실시간 컴퓨터 비전(시각처리)을 목적으로 프로그래밍 라이브러리
# - 인텔에서 2000년에 C, C++ 사용하기 위해서 개발
# - 파이썬에서 사용할 수 있게 래핑
#
# ```shell
# > pip install opencv-python
# ```

# %%
# opencv 설치
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from opencv-python) (1.26.4)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
cv2.__version__
# Out:
# '4.11.0'

# %%
img2 = cv2.imread('./predict_result.jpg')
img2.shape          # (464, 640, 3) -> (height, width, channel)
# Out:
# (464, 640, 3)

# %%
# 윈도우 창 오픈
cv2.imshow('predict_result', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### YOLO 예측

# %%
img = cv2.imread('./0000002.jpg')
resized_img = cv2.resize(img, (640,400))

result = model(resized_img)
plots = result[0].plot()

cv2.imshow('predict_result', plots)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 416x640 1 bottle, 1 cup, 1 bowl, 1 tv, 1 mouse, 1 book, 238.9ms
# Speed: 3.8ms preprocess, 238.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)

# %% [markdown]
# #### 동영상 플레이
# - 라즈베리파이에서 동일하게 사용가능
# - 라즈베리파이 웹캠 사용추천

# %%
# 비디오 파일 경로
video_path = './sample01.mp4'
ouput_path = './sample01_output.mp4'
count_path = './sample01_count.mp4'

# %%
# 동영상 플레이
cap = cv2.VideoCapture(video_path)      # 0 -> 웹캡이나 카메라 설치된 번호

while cap.isOpened():
    ret, frame = cap.read()
    if not ret: break
    
    cv2.imshow('Video play', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):   # q버튼을 누르면
        break

cap.release()       # 비디오를 해제
cv2.destroyAllWindows()

# %% [markdown]
# #### YOLO 실시간 예측

# %%
# 시간 모듈 로드
import time

# %%
cap = cv2.VideoCapture(video_path) 

fps = cap.get(cv2.CAP_PROP_FPS)     # 동영상 FPS(Frame Per Second)
frame_time = 1.0 / fps  # 초단위로 변환
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))      # 1280
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))    # 720

# VideoWriter 객체 생성(동영상 화면에 그림, 글자를 그리기 위한 객체)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(ouput_path, fourcc, fps, (width, height))

while cap.isOpened():
    start_time = time.time()        # 시작시간
    ret, frame = cap.read()
    if not ret: break
    
    # 객체 탐지
    results = model(frame)
    # 탐지 결과 그리기
    for result in results:
        detect_fame = result.plot()
    # 결과프레임을 파일로 저장
    out.write(detect_fame)
    # 결과 표시
    cv2.imshow('YOLO object Detction', detect_fame)
    cv2.imshow('Video play', frame)

    # 프레임간 실제 지연시간 계산
    elapsed_time = time.time() - start_time
    delay = max(int((frame_time - elapsed_time) * 1000),1)

    if cv2.waitKey(1) & 0xFF == ord('q'):   # q버튼을 누르면
        break

out.release()
cap.release()       # 비디오를 해제
cv2.destroyAllWindows()

# %% [markdown]
# #### Car Counting
# - 지정된 라인 아래로 내려오는 자동차 개수 카운팅

# %% [markdown]
# - shapely 설치
#
# ```shell
# > pip install shapely==2.0.1
# ```

# %%
# shapely 설치
# !pip install shapely==2.0.1
# Out:
# Collecting shapely==2.0.1
#   Downloading shapely-2.0.1-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy>=1.14 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from shapely==2.0.1) (1.26.4)
# Downloading shapely-2.0.1-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.4 MB 2.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 7.9 MB/s eta 0:00:00
# Installing collected packages: shapely
# Successfully installed shapely-2.0.1
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# lap 설치
# !pip install lap
# Out:
# Collecting lap
#   Downloading lap-0.5.12-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\source\iot-dataanalysis-2025\mlvenv\lib\site-packages (from lap) (1.26.4)
# Downloading lap-0.5.12-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.2/1.5 MB 2.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.5 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
from ultralytics import solutions

# %%
import cv2
from ultralytics.solutions import ObjectCounter

cap = cv2.VideoCapture(video_path) 
assert cap.isOpened(), 'Error reading video file'    # 파일 열리지 않으면 경고처리

region_points = [(20,400),(1080,400)]       # 라인수

fps = cap.get(cv2.CAP_PROP_FPS)     # 동영상 FPS(Frame Per Second)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))      # 1280
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))    # 720
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(count_path, fourcc, fps, (width, height))
# 물체 인식 핵심 객체
counter = ObjectCounter(
    show=True,          # 처리중 화면에 디스플레이
    region=region_points,       # 라인위치
    model='yolo11n.pt',         # YOLO 모델
)


while cap.isOpened():
    ret, frame = cap.read()
    if not ret: break
    
    results = counter(frame)
    out.write(results.plot_im)      # 여기 차이

out.release()
cap.release()       # 비디오를 해제
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions:  {'region': [(20, 400), (1080, 400)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': 'yolo11n.pt', 'line_width': 3}
#
# 0: 384x640 1 train, 49.4ms
# Speed: 3.2ms preprocess, 49.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 car, 1 train, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 2 cars, 1 train, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 3 cars, 1 train, 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.1ms
# Speed: 2.9ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 5 cars, 1 train, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 12.0ms
# Speed: 1.3ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 4 cars, 1 train, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 3 cars, 1 train, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 4 cars, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 4 cars, 12.4ms
# Speed: 1.5ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 4 cars, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 5 cars, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 6 cars, 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 6 cars, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 12.4ms
# Speed: 1.6ms preprocess, 12.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 19.2ms
# Speed: 2.5ms preprocess, 19.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 3 cars, 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 3 cars, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 4 cars, 1 train, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.2ms
# Speed: 1.4ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.1ms
# Speed: 1.4ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 2 cars, 2 trains, 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 2 cars, 1 train, 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 3 cars, 1 train, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 4 cars, 1 train, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.2ms
# Speed: 1.4ms preprocess, 12.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 3 cars, 2 trains, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 13.8ms
# Speed: 1.4ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 13.6ms
# Speed: 1.6ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 2, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 5 cars, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 toilet, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 3, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 4, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 4, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 14.4ms
# Speed: 1.5ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 2 cars, 2 trains, 13.7ms
# Speed: 1.4ms preprocess, 13.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 2 cars, 2 trains, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 5 cars, 1 train, 1 truck, 13.5ms
# Speed: 1.3ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 3 cars, 1 train, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 2 cars, 1 train, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 3 cars, 1 train, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 1 car, 1 train, 1 traffic light, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 1 car, 1 train, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 2 cars, 1 train, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 2 cars, 1 train, 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 1 car, 1 train, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 20.1ms
# Speed: 3.5ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 22.3ms
# Speed: 2.0ms preprocess, 22.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 25.3ms
# Speed: 1.9ms preprocess, 25.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 train, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 train, 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=1)
#
# 0: 384x640 1 car, 1 train, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 1 car, 1 train, 13.9ms
# Speed: 1.4ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=2)
#
# 0: 384x640 2 cars, 1 train, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=3)
#
# 0: 384x640 3 cars, 1 train, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 3 cars, 1 train, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 4 cars, 1 train, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 4 cars, 1 train, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 12.1ms
# Speed: 1.3ms preprocess, 12.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 1 train, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 4 cars, 1 train, 10.4ms
# Speed: 1.7ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 1 train, 12.9ms
# Speed: 2.2ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 4 cars, 1 train, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 1 train, 14.5ms
# Speed: 2.7ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 5, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# ...
#
# 0: 384x640 7 cars, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 7 cars, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 7 cars, 12.1ms
# Speed: 1.4ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 8 cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 7 cars, 1 train, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 6 cars, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 6 cars, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 5 cars, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 12.3ms
# Speed: 1.4ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 12.4ms
# Speed: 1.5ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=9, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 9, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 6 cars, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 6 cars, 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 6 cars, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 6 cars, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 6 cars, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=10, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 10, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 6 cars, 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=6)
#
# 0: 384x640 4 cars, 1 train, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 28.1ms
# Speed: 1.9ms preprocess, 28.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 4 cars, 22.4ms
# Speed: 1.9ms preprocess, 22.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 4 cars, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 4 cars, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=4)
#
# 0: 384x640 5 cars, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
#
# 0: 384x640 5 cars, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=11, classwise_count={'train': {'IN': 0, 'OUT': 0}, 'car': {'IN': 11, 'OUT': 0}, 'toilet': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'traffic light': {'IN': 0, 'OUT': 0}, 'suitcase': {'IN': 0, 'OUT': 0}}, total_tracks=5)
